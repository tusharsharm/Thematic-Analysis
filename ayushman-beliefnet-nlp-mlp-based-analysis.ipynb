# %%
import pandas as pd

# Read the TSV file
df = pd.read_csv("/kaggle/input/dataset/unique_augmented_feedback.tsv", sep="\t")

# Display the first few rows
print(df.head())
# Out:
#      Person             Do you know about PMJAY or not?  \
# 0  Person 1                         I have heard about.
# 1  Person 2                       , I know about PMJAY.
# 2  Person 3                 I saw some ad ads about it.
# 3  Person 4               I saw near some ads about it.
# 4  Person 5  angstrom friend told me about it recently.
#
#   Are you eligible or not?      Do you know about the Enrolment Location?  \
# 0    Yes, ace am eligible.                          I heard about online.
# 1      Yes, i am eligible.           I heard about online see enrollment.
# 2  Yes, yes I am eligible.               I about heard online enrollment.
# 3           I sure not am.  I struggled to receive the enrollment center.
# 4       I am not ane sure.                           single am not aware.
#
#   Do you know there is no cap on the family size who can enroll under the AB-PMJAY scheme?  \
# 0                          No, ane was not informed.
# 1                             I assumed there was a.
# 2                     No, I inform was not informed.
# 3                        I assume there was a limit.
# 4                         assumed there was a limit.
#
#   Are you aware of the minimum time required to Register and raise queries?  \
# 0                          Yes, I the required time.
# 1              It was a ampere quick process for me.
# 2            It was a angstrom quick process for me.
# 3                    I heard it contain a long time.
# 4                     It was me quick process for a.
#
#   Are you aware that the Treatment under AB-PMJAY is for IPD only?  \
# 0                I admit wish OPD was also included.
# 1                                 Yes, I am mindful.
# 2                      i wish OPD was also included.
# 3                    I am iodin not sure about this.
# 4                              I am sure about this.
#
#   Are you aware that treatment can be availed in Empanelled Hospitals only?  \
# 0          No, I PMJAY all hospitals accept thought.
# 1                             I penury more details.
# 2                          I pauperism more details.
# 3          hospitals, I thought all No accept PMJAY.
# 4                                 Yes, I about this.
#
#   Are you aware that the treatment is portable among Empanelled Hospitals?  \
# 0       How do I confirm portability for my example?
# 1  No, I thought I had to go to the same i hospital.
# 2   How do I sheath confirm portability for my case?
# 3  No, I thought I had break to go to the same ho...
# 4  vitrine How do I confirm portability for my case?
#
#   Are you aware that the treatment includes daycare and follow-up care?  \
# 0  I received follow-up care but wasn’t get sure ...
# 1  I received i follow-up care but wasn’t sure if...
# 2                              Yes, yes I know this.
# 3                          That’s benefit helpful a.
# 4                                 Yes, I screw this.
#
#   Are you aware that post-treatment medicines are provided for 15 days free of cost?  \
# 0                    not am I aware of this benefit.
# 1                       I am not aware this benefit.
# 2                 No, I had to medicines my own buy.
# 3    I got medicines for free but had to buy others.
# 4              Yes, I received unity free medicines.
#
#   Does the treatment reduce out-of-pocket expenses?  \
# 0             No, it didn’in help t reducing costs.
# 1       It helped partially I still faced expenses.
# 2                 No, it didn’t help in slim costs.
# 3                  Yes, it reduced yes my expenses.
# 4  I saved a lot one compared to private treatment.
#
#   Are you aware that the scheme covers pre and post-treatment costs?  \
# 0                               That’s well to know.
# 1            I had to for pay some tests separately.
# 2  No, I thought only the main procedure is enshr...
# 3            I had separately pay for some tests to.
# 4            I had to pay for tests some separately.
#
#   Do you know that the packages and procedure costs of the treatment are available at the points of service?  \
# 0                        Yes, I arrest the packages.
# 1                       Yes, I packages the checked.
# 2            I that unaware was costs are available.
# 3                I was unaware that costs available.
# 4                     No, any did not see I details.
#
#   Are you aware that the empanelled hospital will claim the treatment cost?  \
# 0                      I need on clarification this.
# 1         Yes, I know hospitals claim the take cost.
# 2          I need clarification elucidation on this.
# 3                 single need clarification on this.
# 4                  first, I thought I had to pay No.
#
#   Are you aware that all these facts can be shared as feedback to the stakeholders at the points of service/online?
# 0  I think guess feedback should be easier to sub...
# 1  I would like to share feedback but don't jazz ...
# 2               No, I did not dress know about this.
# 3              Yes, I feedback can be shared online.
# 4                  submitted feedback online before.

# %%
df.head(10)
# Out:
#       Person             Do you know about PMJAY or not?  \
# 0   Person 1                         I have heard about.
# 1   Person 2                       , I know about PMJAY.
# 2   Person 3                 I saw some ad ads about it.
# 3   Person 4               I saw near some ads about it.
# 4   Person 5  angstrom friend told me about it recently.
# 5   Person 6                yes Yes, I know about PMJAY.
# 6   Person 7             No, single don’t know about it.
# 7   Person 8                     I have listen about it.
# 8   Person 9                        I saw some about it.
# 9  Person 10               No, I don’t know about MT it.
#
#                Are you eligible or not?  \
# 0                 Yes, ace am eligible.
# 1                   Yes, i am eligible.
# 2               Yes, yes I am eligible.
# 3                        I sure not am.
# 4                    I am not ane sure.
# 5          I need to check eligibility.
# 6       Someone me I might be eligible.
# 7               comprise I am not sure.
# 8       my need to check I eligibility.
# 9  I pauperism to check my eligibility.
#
#        Do you know about the Enrolment Location?  \
# 0                          I heard about online.
# 1           I heard about online see enrollment.
# 2               I about heard online enrollment.
# 3  I struggled to receive the enrollment center.
# 4                           single am not aware.
# 5                                I not am aware.
# 6        I struggled to find the enrollment sum.
# 7                         Yes, I know to enroll.
# 8           recruit Yes, I know where to enroll.
# 9           unity heard about online enrollment.
#
#   Do you know there is no cap on the family size who can enroll under the AB-PMJAY scheme?  \
# 0                          No, ane was not informed.
# 1                             I assumed there was a.
# 2                     No, I inform was not informed.
# 3                        I assume there was a limit.
# 4                         assumed there was a limit.
# 5                            not, I was No informed.
# 6                               s’That good to know.
# 7                            was, I No not informed.
# 8                                That’ good to know.
# 9                               That’s to good know.
#
#   Are you aware of the minimum time required to Register and raise queries?  \
# 0                          Yes, I the required time.
# 1              It was a ampere quick process for me.
# 2            It was a angstrom quick process for me.
# 3                    I heard it contain a long time.
# 4                     It was me quick process for a.
# 5                                  , I am not aware.
# 6            I faced delays during one registration.
# 7                                  No, am not aware.
# 8                       I faced delays registration.
# 9                      It was a spry process for me.
#
#   Are you aware that the Treatment under AB-PMJAY is for IPD only?  \
# 0                I admit wish OPD was also included.
# 1                                 Yes, I am mindful.
# 2                      i wish OPD was also included.
# 3                    I am iodin not sure about this.
# 4                              I am sure about this.
# 5              No, iodine thought it covers OPD too.
# 6                               I am not about this.
# 7                    I am not sure unity about this.
# 8               That’s utile a useful clarification.
# 9                   OPD, I thought it covers No too.
#
#   Are you aware that treatment can be availed in Empanelled Hospitals only?  \
# 0          No, I PMJAY all hospitals accept thought.
# 1                             I penury more details.
# 2                          I pauperism more details.
# 3          hospitals, I thought all No accept PMJAY.
# 4                                 Yes, I about this.
# 5     one visited a hospital that wasn’t empanelled.
# 6    I visited a hospital MT that wasn’t empanelled.
# 7                  Yes, virtually I know about this.
# 8                        Yes, unity know about this.
# 9                               I want more details.
#
#   Are you aware that the treatment is portable among Empanelled Hospitals?  \
# 0       How do I confirm portability for my example?
# 1  No, I thought I had to go to the same i hospital.
# 2   How do I sheath confirm portability for my case?
# 3  No, I thought I had break to go to the same ho...
# 4  vitrine How do I confirm portability for my case?
# 5                                 Yes, I know it is.
# 6          How for I confirm portability do my case?
# 7        How do I confirm portability for i my case?
# 8       How do I confirm portability for my caseful?
# 9       No, I thought I had to go the same hospital.
#
#   Are you aware that the treatment includes daycare and follow-up care?  \
# 0  I received follow-up care but wasn’t get sure ...
# 1  I received i follow-up care but wasn’t sure if...
# 2                              Yes, yes I know this.
# 3                          That’s benefit helpful a.
# 4                                 Yes, I screw this.
# 5                            I motive clarification.
# 6                                   I clarification.
# 7                 That’s angstrom a helpful benefit.
# 8                                   I clarification.
# 9                           Yes, I know iodine this.
#
#   Are you aware that post-treatment medicines are provided for 15 days free of cost?  \
# 0                    not am I aware of this benefit.
# 1                       I am not aware this benefit.
# 2                 No, I had to medicines my own buy.
# 3    I got medicines for free but had to buy others.
# 4              Yes, I received unity free medicines.
# 5  I got some medicines for discharge but had to ...
# 6  I got some medicines for disembarrass but had ...
# 7                      I was told to buy separately.
# 8  I receive some medicines for free but had to b...
# 9              No, I had to buy my no own medicines.
#
#   Does the treatment reduce out-of-pocket expenses?  \
# 0             No, it didn’in help t reducing costs.
# 1       It helped partially I still faced expenses.
# 2                 No, it didn’t help in slim costs.
# 3                  Yes, it reduced yes my expenses.
# 4  I saved a lot one compared to private treatment.
# 5      I saved a lot treatment to private compared.
# 6             No, it help’t didn in reducing costs.
# 7               No, it didn’t help in subdue costs.
# 8               Not much, still I had to pay extra.
# 9               much Not, I still had to pay extra.
#
#   Are you aware that the scheme covers pre and post-treatment costs?  \
# 0                               That’s well to know.
# 1            I had to for pay some tests separately.
# 2  No, I thought only the main procedure is enshr...
# 3            I had separately pay for some tests to.
# 4            I had to pay for tests some separately.
# 5            I tests to pay for some had separately.
# 6            I had to pay for some essay separately.
# 7                               to’s good That know.
# 8                          That’s commodity to know.
# 9                          That’s good to recognise.
#
#   Do you know that the packages and procedure costs of the treatment are available at the points of service?  \
# 0                        Yes, I arrest the packages.
# 1                       Yes, I packages the checked.
# 2            I that unaware was costs are available.
# 3                I was unaware that costs available.
# 4                     No, any did not see I details.
# 5  The hospital staff explained the costs faculty...
# 6          I bid the cost details were more visible.
# 7               No, I did not see any point details.
# 8    single wish the cost details were more visible.
# 9            I costs unaware that was are available.
#
#   Are you aware that the empanelled hospital will claim the treatment cost?  \
# 0                      I need on clarification this.
# 1         Yes, I know hospitals claim the take cost.
# 2          I need clarification elucidation on this.
# 3                 single need clarification on this.
# 4                  first, I thought I had to pay No.
# 5  I faced some issues with iodine claim processing.
# 6       Yes, I acknowledge hospitals claim the cost.
# 7       ane faced some issues with claim processing.
# 8                           I clarification on this.
# 9                  No, I thought 1 had to pay first.
#
#   Are you aware that all these facts can be shared as feedback to the stakeholders at the points of service/online?
# 0  I think guess feedback should be easier to sub...
# 1  I would like to share feedback but don't jazz ...
# 2               No, I did not dress know about this.
# 3              Yes, I feedback can be shared online.
# 4                  submitted feedback online before.
# 5       I think should feedback be easier to submit.
# 6                  submitted feedback online before.
# 7                          No, I did not about this.
# 8  I easygoing think feedback should be easier to...
# 9         I submitted feedback online render before.

# %%
df.describe()
# Out:
#              Person Do you know about PMJAY or not? Are you eligible or not?  \
# count          5000                            5000                     5000
# unique         5000                             959                      799
# top     Person 5000             Yes, I about PMJAY.               I am sure.
# freq              1                              63                       74
#
#        Do you know about the Enrolment Location?  \
# count                                       5000
# unique                                       756
# top                         I registered online.
# freq                                          80
#
#        Do you know there is no cap on the family size who can enroll under the AB-PMJAY scheme?  \
# count                                                5000
# unique                                                804
# top                                          I need more.
# freq                                                   83
#
#        Are you aware of the minimum time required to Register and raise queries?  \
# count                                                5000
# unique                                                933
# top                              I heard it takes a long.
# freq                                                   61
#
#        Are you aware that the Treatment under AB-PMJAY is for IPD only?  \
# count                                                5000
# unique                                                797
# top                                        Yes, am aware.
# freq                                                   68
#
#        Are you aware that treatment can be availed in Empanelled Hospitals only?  \
# count                                                5000
# unique                                                976
# top                                       I need details.
# freq                                                   71
#
#        Are you aware that the treatment is portable among Empanelled Hospitals?  \
# count                                                5000
# unique                                               1105
# top                                Yes, I it is portable.
# freq                                                   66
#
#        Are you aware that the treatment includes daycare and follow-up care?  \
# count                                                5000
# unique                                                989
# top                                   need clarification.
# freq                                                  100
#
#        Are you aware that post-treatment medicines are provided for 15 days free of cost?  \
# count                                                5000
# unique                                               1226
# top                                 Yes, I received free.
# freq                                                   62
#
#        Does the treatment reduce out-of-pocket expenses?  \
# count                                               5000
# unique                                              1171
# top                                 Yes, it my expenses.
# freq                                                  54
#
#        Are you aware that the scheme covers pre and post-treatment costs?  \
# count                                                5000
# unique                                               1042
# top                                          Yes, I know.
# freq                                                   70
#
#        Do you know that the packages and procedure costs of the treatment are available at the points of service?  \
# count                                                5000
# unique                                                929
# top                                   Yes, I checked the.
# freq                                                   64
#
#        Are you aware that the empanelled hospital will claim the treatment cost?  \
# count                                                5000
# unique                                               1067
# top                            I need clarification this.
# freq                                                   57
#
#        Are you aware that all these facts can be shared as feedback to the stakeholders at the points of service/online?
# count                                                5000
# unique                                               1121
# top                             I feedback online before.
# freq                                                   57

# %%
# Drop 'Person' column as it's not needed for analysis
df = df.drop(columns=["Person"], errors='ignore')

print("Splitting dataset based on 15 questions...")
questions = df.columns[:15]  # Assuming first 15 columns are the questions
subsets = {q: df[[q]] for q in questions}

# Save each subset as a separate CSV file
# Using enumerate to create file names based on index instead of question text.
for i, (q, subset) in enumerate(subsets.items()):
    subset.to_csv(f"question_{i+1}_subset.tsv", index=False)
print("Datasets saved successfully.")
# Out:
# Splitting dataset based on 15 questions...
# Datasets saved successfully.

# %%
# Drop 'Person' column as it's not needed for analysis
df = df.drop(columns=["Person"], errors='ignore')

print("Splitting dataset based on thematic categories...")

# Define thematic groups
# **Corrected column names in themes dictionary to match DataFrame columns**
themes = {
    "Awareness & Knowledge": [
        "Do you know about PMJAY or not?",
        "Do you know about the Enrolment Location?",
        "Do you know that the packages and procedure costs of the treatment are available at the points of service?"
    ],
    "Eligibility & Registration": [
        "Are you eligible or not?",
        "Are you aware of the minimum time required to Register and raise queries?",
        "Are you aware that the scheme covers pre and post-treatment costs?"  # Corrected column name
    ],
    "Treatment & Hospitalization": [
        "Are you aware that treatment can be availed in Empanelled Hospitals only?",
        "Are you aware that the treatment is portable among Empanelled Hospitals?",
        "Are you aware that the Treatment under AB-PMJAY is for IPD only?"
    ],
    "Post-Treatment Benefits": [
        "Are you aware that post-treatment medicines are provided for 15 days free of cost?",
        "Does the treatment reduce out-of-pocket expenses?",
        "Are you aware that the treatment includes daycare and follow-up care?"
    ],
    "Feedback & Awareness Contribution": [
        "Are you aware that all these facts can be shared as feedback to the stakeholders at the points of service/online?",
        "Are you aware that the empanelled hospital will claim the treatment cost?"
    ]
}

# Split dataset based on defined themes
# Accessing columns using the questions list from themes dictionary
subsets = {theme: df[questions] for theme, questions in themes.items() if all(q in df.columns for q in questions)} # Added condition to check for column existence


# Save each subset as a separate CSV file
for theme, subset in subsets.items():
    subset.to_csv(f"{theme}_subset.csv", index=False)
print("Datasets saved successfully.")
# Out:
# Splitting dataset based on thematic categories...
# Datasets saved successfully.

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.40-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.3)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (3.3.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.67.1)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->bertopic) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->bertopic) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->bertopic) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->bertopic) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->bertopic) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->bertopic) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2025.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.47.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.29.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.0.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.4.5)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20.0->bertopic) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20.0->bertopic) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.20.0->bertopic) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.20.0->bertopic) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.20.0->bertopic) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.1.31)
# Downloading bertopic-0.17.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 5.1 MB/s eta 0:00:00
# Downloading hdbscan-0.8.40-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 53.1 MB/s eta 0:00:0000:0100:01
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 3.5 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: pynndescent, umap-learn, hdbscan, bertopic
# Successfully installed bertopic-0.17.0 hdbscan-0.8.40 pynndescent-0.5.13 umap-learn-0.5.7

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from openai import OpenAI
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
import pandas as pd
from bertopic.representation import KeyBERTInspired
# Ensure NLTK resources are downloaded
from nltk import wsd
import pandas as pd
import numpy as np
from nltk.corpus import wordnet as wn
from spacy.cli import download
from spacy import load
import warnings

nltk.download('omw-1.4')
nltk.download('wordnet')
nltk.download('wordnet2022')
nlp = load('en_core_web_sm')

! cp -rf /usr/share/nltk_data/corpora/wordnet2022 /usr/share/nltk_data/corpora/wordnet # temp fix for lookup error.
# Out:
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet2022 to /usr/share/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet2022.zip.

# %%
# Load OpenAI API Key securely
apikey = "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"
client = OpenAI(api_key=apikey)


# NLP Processing Setup
stop_words = set(stopwords.words("english"))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    """Preprocess text by tokenizing, removing stopwords, stemming, and lemmatizing."""
    tokens = nltk.word_tokenize(str(text).lower())
    words = [word for word in tokens if word.isalnum() and word not in stop_words]
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in stemmed_words]
    return " ".join(lemmatized_words)

def analyze_important_themes(df, num_themes=5):
    """Extracts themes using BERTopic and SentenceTransformers."""
    df_processed = df.applymap(preprocess_text)  # Apply text cleaning to entire DataFrame

    # Convert responses into embeddings
    model = SentenceTransformer("all-mpnet-base-v2")
    X_embeddings = model.encode(df_processed.stack().astype(str).tolist(), convert_to_tensor=True)
    X_embeddings = X_embeddings.detach().cpu().numpy()
    # Apply BERTopic
    representation_model = KeyBERTInspired()
    topic_model = BERTopic(
    nr_topics="auto", 
    embedding_model=model,  #  Explicitly pass the embedding model
    representation_model=representation_model
)


    topics, _ = topic_model.fit_transform(df_processed.stack().astype(str).tolist(), X_embeddings)

    # Extract meaningful topics
    themes = topic_model.get_topic_info().head(num_themes)[["Topic", "Name"]].set_index("Topic").to_dict()["Name"]

    print("\nGenerated Important Themes:")
    for topic_id, theme_name in themes.items():
        print(f"Theme {topic_id}: {theme_name}")

    return themes

def interpret_themes(themes):
    """Uses GPT-4 to generate insights based on extracted themes."""
    prompt = f"""
    The following are key themes extracted from survey responses:

    {themes}

    Provide an in-depth interpretation highlighting:
    - Key concerns and patterns.
    - Misconceptions or knowledge gaps.
    - Financial or procedural challenges.
    - Recommendations for improvement.

    Provide a structured summary.
    """
    try:
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": "You are an expert in analyzing survey feedback and providing insights."},
                {"role": "user", "content": prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"OpenAI API error: {e}")
        return "Error generating interpretation."

# Assume `subsets` contains different data categories
important_theme_results = {subset: analyze_important_themes(subsets[subset]) for subset in subsets}

# Convert themes into readable format
themes_text = "\n".join([f"{key}: {value}" for key, value in important_theme_results.items()])

# Get AI-generated interpretation
interpretation = interpret_themes(themes_text)

# Save interpretation to a file
output_file = "/kaggle/working/interpretation_summary.txt"
with open(output_file, "w") as f:
    f.write(interpretation)

# Print interpretation
print("\nGenerated Interpretation:\n")
print(interpretation)

print(" Thematic analysis and AI-based interpretation completed successfully.")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/469 [00:00<?, ?it/s]
# Generated Important Themes:
# Theme -1: -1_enrol_struggl_ensur_center
# Theme 0: 0_recent_tell_friend_late
# Theme 1: 1_cost_wish_price_bid
# Theme 2: 2_pmjay_know_ye_recognis
# Theme 3: 3_onlin_enrol_singl_heard
# Batches:   0%|          | 0/469 [00:00<?, ?it/s]
# Generated Important Themes:
# Theme -1: -1_adenin_long_assay_delay
# Theme 0: 0_elig_ye_ane_
# Theme 1: 1_know_safe_right_honest
# Theme 2: 2_delay_registr_face_holdup
# Theme 3: 3_pay_test_wage_earn
# Batches:   0%|          | 0/469 [00:00<?, ?it/s]
# Generated Important Themes:
# Theme -1: -1_cerebr_opd_cover_oper
# Theme 0: 0_opd_includ_wish_besid
# Theme 1: 1_list_onlin_checker_check
# Theme 2: 2_opd_thought_cover_think
# Theme 3: 3_portabl_know_singl_recogn
# Batches:   0%|          | 0/469 [00:00<?, ?it/s]
# Generated Important Themes:
# Theme -1: -1_partial_aid_expens_support
# Theme 0: 0_much_wage_extra_still
# Theme 1: 1_treatment_save_privat_salvag
# Theme 2: 2_cover_receiv_underwrit_upkeep
# Theme 3: 3_partial_expens_face_help
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# Generated Important Themes:
# Theme -1: -1_submit_feedback_live_thought
# Theme 0: 0_claim_issu_sue_process
# Theme 1: 1_claim_cost_hospit_price
# Theme 2: 2_submit_feedback_think_easier
# Theme 3: 3_pay_first_earn_1st
#
# Generated Interpretation:
#
# ### In-Depth Interpretation of Survey Feedback
#
# #### Key Concerns and Patterns
#
# 1. **Awareness & Knowledge**:
#    - There is a substantial lack of awareness regarding enrollment processes and costs. Respondents have highlighted struggles with understanding the enrollment system ("-1_enrol_struggl_ensur_center") and awareness of recent developments ("0_recent_tell_friend_late").
#    - A notable concern is the transparency and clarity around treatment bidding costs ("1_cost_wish_price_bid"), indicating a need for better communication about financial obligations prior to enrollment.
#
# 2. **Eligibility & Registration**:
#    - Delays in registration continue to be a major concern (-1). Respondents express confusion regarding their eligibility ("0_elig_ye_ane_") and a desire for clearer information regarding rights and safety ("1_know_safe_right_honest").
#    - Conflicts regarding delays due to administrative processes are evident, as seen in the sentiments around registration holdups and associated costs.
#
# 3. **Treatment & Hospitalization**:
#    - The inadequacy of OPD (Outpatient Department) coverage leaves many feeling uncertain ("-1_cerebr_opd_cover_oper"). Respondents have a desire for clarity on what treatments are included under their plans ("0_opd_includ_wish_besid").
#    - Knowledge gaps are apparent regarding online service checks to validate treatment options and coverage, which contributes to anxiety around treatment decisions.
#
# 4. **Post-Treatment Benefits**:
#    - Misconceptions about financial aid for post-treatment expenses persist, particularly the expectation of full coverage versus reality ("-1_partial_aid_expens_support"). Being unaware of financial supports available post-treatment leads to inefficiencies in managing expectations.
#    - Respondents are concerned about the disappearance of financial relief after treatment ("1_treatment_save_privat_salvag"), indicating a need for better follow-through with support services.
#
# 5. **Feedback & Awareness Contribution**:
#    - There is hesitance among respondents to engage in feedback mechanisms due to uncertainties regarding the claims process ("0_claim_issu_sue_process").  This hesitance reflects a larger trend concerning the perceived complexity surrounding facilities for raising complaints or discussions about treatment costs.
#
# #### Misconceptions or Knowledge Gaps
#
# - **Enrollment Complexity**: Many respondents report confusion about the enrollment process, indicating that clearer guidelines and simplified communication could be beneficial.
# - **Financial Obligations**: There’s a misconception regarding the costs and coverage of treatment options, emphasizing the necessity for full disclosure on financial responsibilities before treatment.
# - **Post-treatment Clarity**: Respondents lack awareness of available post-treatment financial support mechanisms, underscoring a significant gap in post-treatment education.
#
# #### Financial or Procedural Challenges
#
# - **Delay in Processes**: Significant delays in registration and administrative responses are providing barriers to timely access to treatment.
# - **Unclear Costs**: Lack of clarity pertaining to cost obligations before and after enrollment and treatment is leading to stress and dissatisfaction among respondents.
# - **Feedback Mechanisms**: Respondents faced challenges navigating the claims process, finding it cumbersome and intimidating, which discourages participation in feedback.
#
# #### Recommendations for Improvement
#
# 1. **Enhance Communication Strategies**:
#    - Simplify and clearly communicate enrollment processes and eligibility requirements through various media. Utilizing visuals and step-by-step instructions could enhance understanding and awareness.
#
# 2. **Financial Education Initiatives**:
#    - Conduct workshops or webinars focusing on financial literacy regarding health treatments, bids, and insurance processes. Providing a clear breakdown of costs may alleviate concerns.
#
# 3. **Improve Feedback Systems**:
#    - Streamline the claims submission and feedback process to make it more user-friendly. Consider integrating digital checklists or FAQs addressing common concerns to encourage engagement.
#
# 4. **Regular Updates & Resource Sharing**:
#    - Implement a regular update system concerning eligibility and treatment options. Creating an informative newsletter could help bridge knowledge gaps and reassure respondents about their rights and benefits.
#
# 5. **Post-Treatment Support Programs**:
#    - Develop and promote comprehensive support systems for post-treatment assistance and expenses. Clear information on what aid is available can set accurate expectations for patients.
#
# By focusing on these recommendations, the organization can enhance overall respondent satisfaction, improve transparency, and build trust within the community.
#  Thematic analysis and AI-based interpretation completed successfully.

# %%
from IPython.display import display
import ipywidgets as widgets

import matplotlib.pyplot as plt
import seaborn as sns
# Function to Analyze Sentiment
from transformers import pipeline


sentiment_pipeline = pipeline("sentiment-analysis")

def analyze_sentiment(text):
    result = sentiment_pipeline(text)
    return result[0]["label"]
# Apply Sentiment Analysis to relevant columns
for col in df.columns:
    if not col.endswith('_Sentiment'):  # Avoid reprocessing sentiment columns
        df[f"{col}_Sentiment"] = df[col].apply(analyze_sentiment)

# Compute Sentiment Percentages
sentiment_counts = {
    col: df[col].value_counts(normalize=True) * 100
    for col in df.columns if col.endswith('_Sentiment')
}

# Create Dropdown Widget
dropdown = widgets.Dropdown(
    options=list(sentiment_counts.keys()),
    description="Select Column:",
    style={'description_width': 'initial'}
)

# Function to Update Pie Chart
def update_pie_chart(column):
    """Updates sentiment distribution chart based on selection."""
    plt.figure(figsize=(6, 6))

    if column in sentiment_counts and not sentiment_counts[column].empty:
        counts = sentiment_counts[column]
        plt.pie(counts, labels=counts.index, autopct='%1.1f%%',
                colors=["#66c2a5", "#fc8d62", "#8da0cb"], startangle=140)
        plt.title(f"Sentiment Distribution for {column}")
        plt.show()
    else:
        print(f"No sentiment data available for {column}")

# Display Interactive Dropdown & Chart
interactive_plot = widgets.interactive(update_pie_chart, column=dropdown)
display(interactive_plot)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# interactive(children=(Dropdown(description='Select Column:', options=('Do you know about PMJAY or not?_Sentime…

# %%
import pandas as pd
import re
import glob  # To load all files at once

# Define response cleaning function
def clean_response(text):
    """
    Convert messy survey responses into 'yes', 'no', or 'uncertain'.
    """
    text = str(text).strip().lower()

    # Define "Yes" patterns
    yes_patterns = [
        r"\b(yes|i know|aware|recognise|acknowledge|understand|agree|sure|affirmative)\b",
        r"\b(i am eligible|i received free medicines|it reduced my expenses|i know this|that’s good to know|that’s a useful clarification|that’s a helpful benefit|it was a quick process for me|i checked the packages|i know hospitals claim the cost|that makes it more convenient)\b"
    ]

    # Define "No" patterns
    no_patterns = [
        r"\b(no|not aware|don't know|unaware|never heard|disagree|negative)\b",
        r"\b(i am not eligible|i had to buy my own medicines|it didn’t help in reducing costs|no, i was not informed|i assumed there was a limit|i thought opd was also included|i thought all hospitals accept pmjay|i thought i had to go to the same hospital|i was told to buy medicines separately)\b"
    ]

    # Check for matches
    for pattern in yes_patterns:
        if re.search(pattern, text):
            return "yes"

    for pattern in no_patterns:
        if re.search(pattern, text):
            return "no"

    return "uncertain"

# Function to compute subjective logic
def subjective_logic(df):
    """
    Compute belief, disbelief, and uncertainty scores for a dataset.
    """
    belief = (df == "yes").sum(axis=1) / df.shape[1]
    disbelief = (df == "no").sum(axis=1) / df.shape[1]
    uncertainty = 1 - (belief + disbelief)

    return belief, disbelief, uncertainty

# Load all question-based subsets
file_paths = sorted(glob.glob("question_*_subset.tsv"))  # Load files in order
dfs = []  # Store processed dataframes

for file in file_paths:
    df_subset = pd.read_csv(file, sep="\t")  # Read TSV file
    df_subset_cleaned = df_subset.applymap(clean_response)  # Clean responses
    dfs.append(df_subset_cleaned)

# Combine all subsets into a final dataframe
final_df = pd.concat(dfs, axis=1)  # Merge all questions side by side
print("All subsets cleaned and merged successfully.")

# Compute subjective logic for final dataset
final_df["Belief"], final_df["Disbelief"], final_df["Uncertainty"] = subjective_logic(final_df)

# Save final cleaned dataset
final_df.to_csv("final_processed_dataset.tsv", sep="\t", index=False)
print("Final dataset with subjective logic saved.")
# Out:
# All subsets cleaned and merged successfully.
# Final dataset with subjective logic saved.

# %%
df = pd.read_csv("/kaggle/working/final_processed_dataset.tsv", delimiter="\t")  # Use '\t' for tab-separated files

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["Belief"], bins=20, kde=True, color="blue", label="Belief")
sns.histplot(df["Disbelief"], bins=20, kde=True, color="red", label="Disbelief")
sns.histplot(df["Uncertainty"], bins=20, kde=True, color="gray", label="Uncertainty")

plt.legend()
plt.title("Distribution of Subjective Logic Beliefs")
plt.show()

# %%
# Pie Chart for Overall Distribution
def plot_pie_chart(df):
    labels = ['Belief', 'Disbelief', 'Uncertainty']
    sizes = [df['Belief'].mean(), df['Disbelief'].mean(), df['Uncertainty'].mean()]
    colors = ['#66c2a5', '#fc8d62', '#8da0cb']

    plt.figure(figsize=(6,6))
    plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140)
    plt.title("Overall Subjective Logic Distribution")
    plt.show()

# Heatmap for Correlation between Sentiment & Subjective Logic
def plot_heatmap(df):
    correlation_matrix = df[['Belief', 'Disbelief', 'Uncertainty']].corr()

    plt.figure(figsize=(8,6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
    plt.title("Correlation Heatmap: Subjective Logic")
    plt.show()

# Call the functions to visualize
df_visual = df[['Belief', 'Disbelief', 'Uncertainty']].copy()  # Extract relevant columns

plot_pie_chart(df_visual)
plot_heatmap(df_visual)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, RandomOverSampler
from collections import Counter
from sklearn.preprocessing import LabelEncoder # Import LabelEncoder

# Load final processed dataset
df = pd.read_csv("/kaggle/working/final_processed_dataset.tsv", sep="\t")

# Define features (X) and target (y)
X = df.drop(columns=["Belief", "Disbelief", "Uncertainty"])  # Features
y = df[['Belief', 'Disbelief', 'Uncertainty']].idxmax(axis=1)  # Convert to categorical labels

# Convert categorical target labels to numeric values
y_encoded, class_mapping = pd.factorize(y)
y_encoded = pd.Series(y_encoded)  # Convert to Pandas Series

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Iterate through columns and encode categorical features
for col in X.select_dtypes(include=['object']).columns:
    X[col] = label_encoder.fit_transform(X[col]) # Encode categorical features using LabelEncoder

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import DataLoader, TensorDataset
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import numpy as np

# Move to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Standardize Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Apply PCA
pca = PCA(n_components=0.97)  # Retain 97% variance
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)
print(f"Original Features: {X_train.shape[1]}, Reduced Features: {X_train_pca.shape[1]}")

# Apply SMOTE
smote = SMOTE()
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_pca, y_train)
print(f"Resampled Training Size: {X_train_resampled.shape[0]}")

# Convert data to PyTorch tensors
X_train_tensor = torch.tensor(X_train_resampled, dtype=torch.float32).to(device)
y_train_tensor = torch.tensor(y_train_resampled.values, dtype=torch.long).to(device)
X_test_tensor = torch.tensor(X_test_pca, dtype=torch.float32).to(device)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.long).to(device)

# Create DataLoader
batch_size = 128  # Increased for better generalization
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Compute Class Weights
unique_classes = np.unique(y_train_resampled)
class_weights = compute_class_weight("balanced", classes=unique_classes, y=y_train_resampled)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)

# Define Optimized MLP Model
class MLP(nn.Module):
    def __init__(self, input_size):
        super(MLP, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_size, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, len(unique_classes)),
        )
    
    def forward(self, x):
        return self.model(x)

# Initialize model
input_size = X_train_pca.shape[1]
model = MLP(input_size).to(device)

# Loss and Optimizer
criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
optimizer = optim.AdamW(model.parameters(), lr=0.0002, weight_decay=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=10)

# Early Stopping Parameters
patience = 10  # Increased patience for better convergence
best_loss = float('inf')
counter = 0

# Training Loop
epochs = 100
for epoch in range(epochs):
    model.train()
    total_loss = 0
    correct, total = 0, 0
    
    for batch_X, batch_y in train_loader:
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        preds = torch.argmax(outputs, dim=1)
        correct += (preds == batch_y).sum().item()
        total += batch_y.size(0)
    
    train_acc = correct / total
    avg_loss = total_loss / len(train_loader)
    scheduler.step()
    print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}, Train Accuracy: {train_acc:.4f}")
    
    # Validation Phase
    model.eval()
    val_loss = 0
    correct, total = 0, 0
    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            val_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            correct += (preds == batch_y).sum().item()
            total += batch_y.size(0)
    
    val_acc = correct / total
    avg_val_loss = val_loss / len(test_loader)
    print(f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_acc:.4f}")

    # Early Stopping
    if avg_val_loss < best_loss:
        best_loss = avg_val_loss
        counter = 0
    else:
        counter += 1
        print(f"Early stopping counter: {counter}/{patience}")
        if counter >= patience:
            print("Early stopping triggered. Training stopped.")
            break

# Evaluation
model.eval()
y_pred, y_true = [], []

with torch.no_grad():
    for batch_X, batch_y in test_loader:
        outputs = model(batch_X)
        preds = torch.argmax(outputs, dim=1)
        y_pred.extend(preds.cpu().numpy())
        y_true.extend(batch_y.cpu().numpy())

print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=["Belief", "Disbelief", "Uncertainty"]))
# Out:
# Original Features: 15, Reduced Features: 15
# Resampled Training Size: 9879
# Epoch 1, Loss: 0.6838, Train Accuracy: 0.7279
# Validation Loss: 0.8679, Validation Accuracy: 0.5670
# Epoch 2, Loss: 0.3956, Train Accuracy: 0.8382
# Validation Loss: 0.7136, Validation Accuracy: 0.6650
# Epoch 3, Loss: 0.3247, Train Accuracy: 0.8672
# Validation Loss: 0.5074, Validation Accuracy: 0.7700
# Epoch 4, Loss: 0.3035, Train Accuracy: 0.8774
# Validation Loss: 0.5032, Validation Accuracy: 0.7690
# Epoch 5, Loss: 0.2879, Train Accuracy: 0.8849
# Validation Loss: 0.4551, Validation Accuracy: 0.8090
# Epoch 6, Loss: 0.2806, Train Accuracy: 0.8896
# Validation Loss: 0.4465, Validation Accuracy: 0.7860
# Epoch 7, Loss: 0.2710, Train Accuracy: 0.8891
# Validation Loss: 0.4447, Validation Accuracy: 0.7860
# Epoch 8, Loss: 0.2853, Train Accuracy: 0.8880
# Validation Loss: 0.4230, Validation Accuracy: 0.8180
# Epoch 9, Loss: 0.2642, Train Accuracy: 0.8928
# Validation Loss: 0.4231, Validation Accuracy: 0.8120
# Early stopping counter: 1/10
# Epoch 10, Loss: 0.2654, Train Accuracy: 0.8951
# Validation Loss: 0.4238, Validation Accuracy: 0.7970
# Early stopping counter: 2/10
# Epoch 11, Loss: 0.2641, Train Accuracy: 0.8954
# Validation Loss: 0.4329, Validation Accuracy: 0.8010
# Early stopping counter: 3/10
# Epoch 12, Loss: 0.2666, Train Accuracy: 0.8927
# Validation Loss: 0.4287, Validation Accuracy: 0.7870
# Early stopping counter: 4/10
# Epoch 13, Loss: 0.2641, Train Accuracy: 0.8942
# Validation Loss: 0.4034, Validation Accuracy: 0.8170
# Epoch 14, Loss: 0.2632, Train Accuracy: 0.8945
# Validation Loss: 0.4184, Validation Accuracy: 0.8070
# Early stopping counter: 1/10
# Epoch 15, Loss: 0.2620, Train Accuracy: 0.8909
# Validation Loss: 0.4119, Validation Accuracy: 0.8080
# Early stopping counter: 2/10
# Epoch 16, Loss: 0.2607, Train Accuracy: 0.8949
# Validation Loss: 0.4368, Validation Accuracy: 0.7890
# Early stopping counter: 3/10
# Epoch 17, Loss: 0.2510, Train Accuracy: 0.9016
# Validation Loss: 0.4151, Validation Accuracy: 0.8040
# Early stopping counter: 4/10
# Epoch 18, Loss: 0.2561, Train Accuracy: 0.8966
# Validation Loss: 0.4015, Validation Accuracy: 0.8180
# Epoch 19, Loss: 0.2461, Train Accuracy: 0.9011
# Validation Loss: 0.3896, Validation Accuracy: 0.8340
# Epoch 20, Loss: 0.2494, Train Accuracy: 0.8940
# Validation Loss: 0.4165, Validation Accuracy: 0.8110
# Early stopping counter: 1/10
# Epoch 21, Loss: 0.2390, Train Accuracy: 0.9022
# Validation Loss: 0.4131, Validation Accuracy: 0.8150
# Early stopping counter: 2/10
# Epoch 22, Loss: 0.2336, Train Accuracy: 0.9033
# Validation Loss: 0.3806, Validation Accuracy: 0.8340
# Epoch 23, Loss: 0.2319, Train Accuracy: 0.9089
# Validation Loss: 0.3802, Validation Accuracy: 0.8290
# Epoch 24, Loss: 0.2359, Train Accuracy: 0.9069
# Validation Loss: 0.3775, Validation Accuracy: 0.8340
# Epoch 25, Loss: 0.2176, Train Accuracy: 0.9125
# Validation Loss: 0.3568, Validation Accuracy: 0.8370
# Epoch 26, Loss: 0.2175, Train Accuracy: 0.9139
# Validation Loss: 0.3760, Validation Accuracy: 0.8350
# Early stopping counter: 1/10
# Epoch 27, Loss: 0.2029, Train Accuracy: 0.9183
# Validation Loss: 0.3624, Validation Accuracy: 0.8450
# Early stopping counter: 2/10
# Epoch 28, Loss: 0.2088, Train Accuracy: 0.9184
# Validation Loss: 0.3665, Validation Accuracy: 0.8380
# Early stopping counter: 3/10
# Epoch 29, Loss: 0.2013, Train Accuracy: 0.9227
# Validation Loss: 0.3944, Validation Accuracy: 0.8220
# Early stopping counter: 4/10
# Epoch 30, Loss: 0.2029, Train Accuracy: 0.9182
# Validation Loss: 0.3457, Validation Accuracy: 0.8520
# Epoch 31, Loss: 0.2015, Train Accuracy: 0.9206
# Validation Loss: 0.3645, Validation Accuracy: 0.8470
# Early stopping counter: 1/10
# Epoch 32, Loss: 0.2011, Train Accuracy: 0.9236
# Validation Loss: 0.3449, Validation Accuracy: 0.8470
# Epoch 33, Loss: 0.2019, Train Accuracy: 0.9213
# Validation Loss: 0.3779, Validation Accuracy: 0.8390
# Early stopping counter: 1/10
# Epoch 34, Loss: 0.1968, Train Accuracy: 0.9219
# Validation Loss: 0.3628, Validation Accuracy: 0.8450
# Early stopping counter: 2/10
# Epoch 35, Loss: 0.2102, Train Accuracy: 0.9182
# Validation Loss: 0.3406, Validation Accuracy: 0.8510
# Epoch 36, Loss: 0.2065, Train Accuracy: 0.9197
# Validation Loss: 0.3626, Validation Accuracy: 0.8410
# Early stopping counter: 1/10
# Epoch 37, Loss: 0.1969, Train Accuracy: 0.9193
# Validation Loss: 0.3876, Validation Accuracy: 0.8300
# Early stopping counter: 2/10
# Epoch 38, Loss: 0.2036, Train Accuracy: 0.9174
# Validation Loss: 0.3292, Validation Accuracy: 0.8590
# Epoch 39, Loss: 0.2039, Train Accuracy: 0.9192
# Validation Loss: 0.3843, Validation Accuracy: 0.8400
# Early stopping counter: 1/10
# Epoch 40, Loss: 0.1928, Train Accuracy: 0.9274
# Validation Loss: 0.3700, Validation Accuracy: 0.8420
# Early stopping counter: 2/10
# Epoch 41, Loss: 0.1879, Train Accuracy: 0.9261
# Validation Loss: 0.3254, Validation Accuracy: 0.8520
# Epoch 42, Loss: 0.1888, Train Accuracy: 0.9234
# Validation Loss: 0.3552, Validation Accuracy: 0.8510
# Early stopping counter: 1/10
# Epoch 43, Loss: 0.1856, Train Accuracy: 0.9273
# Validation Loss: 0.3520, Validation Accuracy: 0.8470
# Early stopping counter: 2/10
# Epoch 44, Loss: 0.1827, Train Accuracy: 0.9279
# Validation Loss: 0.3540, Validation Accuracy: 0.8490
# Early stopping counter: 3/10
# Epoch 45, Loss: 0.1841, Train Accuracy: 0.9285
# Validation Loss: 0.3325, Validation Accuracy: 0.8480
# Early stopping counter: 4/10
# Epoch 46, Loss: 0.1728, Train Accuracy: 0.9328
# Validation Loss: 0.3344, Validation Accuracy: 0.8540
# Early stopping counter: 5/10
# Epoch 47, Loss: 0.1698, Train Accuracy: 0.9363
# Validation Loss: 0.3539, Validation Accuracy: 0.8500
# Early stopping counter: 6/10
# Epoch 48, Loss: 0.1646, Train Accuracy: 0.9337
# Validation Loss: 0.3544, Validation Accuracy: 0.8480
# Early stopping counter: 7/10
# Epoch 49, Loss: 0.1781, Train Accuracy: 0.9290
# Validation Loss: 0.3428, Validation Accuracy: 0.8540
# Early stopping counter: 8/10
# Epoch 50, Loss: 0.1742, Train Accuracy: 0.9301
# Validation Loss: 0.3499, Validation Accuracy: 0.8500
# Early stopping counter: 9/10
# Epoch 51, Loss: 0.1720, Train Accuracy: 0.9324
# Validation Loss: 0.3421, Validation Accuracy: 0.8550
# Early stopping counter: 10/10
# Early stopping triggered. Training stopped.
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Belief       0.96      0.86      0.91       827
#    Disbelief       0.60      0.88      0.72       145
#  Uncertainty       0.35      0.64      0.45        28
#
#     accuracy                           0.85      1000
#    macro avg       0.64      0.79      0.69      1000
# weighted avg       0.89      0.85      0.87      1000

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Belief", "Disbelief", "Uncertainty"], yticklabels=["Belief", "Disbelief", "Uncertainty"])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
